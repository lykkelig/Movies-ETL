# %%
## Deliverable 4: Create the Movie Database
import json
import pandas as pd
import numpy as np
import os
import re

from sqlalchemy import create_engine
import psycopg2

from config import db_password
import time

# %%
#  Add the clean movie function that takes in the argument, "movie".
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    # combine alternate titles into one list
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune-Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in movie:
            alt_titles[key] = movie[key]
            movie.pop(key)
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles

    # merge column names
    def change_column_name(old_name, new_name):
        if old_name in movie:
            movie[new_name] = movie.pop(old_name)
    change_column_name('Adaptation by', 'Writer(s)')
    change_column_name('Country of origin', 'Country')
    change_column_name('Directed by', 'Director')
    change_column_name('Distributed by', 'Distributor')
    change_column_name('Edited by', 'Editor(s)')
    change_column_name('Length', 'Running time')
    change_column_name('Original release', 'Release date')
    change_column_name('Music by', 'Composer(s)')
    change_column_name('Produced by', 'Producer(s)')
    change_column_name('Producer', 'Producer(s)')
    change_column_name('Productioncompanies ', 'Production company(s)')
    change_column_name('Productioncompany ', 'Production company(s)')
    change_column_name('Released', 'Release Date')
    change_column_name('Release Date', 'Release date')
    change_column_name('Screen story by', 'Writer(s)')
    change_column_name('Screenplay by', 'Writer(s)')
    change_column_name('Story by', 'Writer(s)')
    change_column_name('Theme music composer', 'Composer(s)')
    change_column_name('Written by', 'Writer(s)')

    return movie

# %%
# Use your knowledge of Python, Pandas, the ETL process, code refactoring, and PostgreSQL to add the 
#   movies_df DataFrame and MovieLens rating CSV data to a SQL database.

def extract_transform_load():
    kaggle_metadata = pd.read_csv(os.path.join('Resources','movies_metadata.csv'), low_memory=False)
    ratings = pd.read_csv(os.path.join('Resources','ratings.csv'))

    # Read the Wikipedia data JSON file.
    with open(os.path.join('Resources','wikipedia-movies.json'), mode='r') as file:
        wiki_movies_raw = json.load(file)    
    
    wiki_movies = [movie for movie in wiki_movies_raw \
                   if ('Director' in movie or 'Directed by' in movie) \
                   and 'imdb_link' in movie \
                   and "No. of episodes" not in movie]

    # Write a list comprehension to iterate through the cleaned wiki movies list
    # and call the clean_movie function on each movie.
    cleaned_wiki_movies = [clean_movie(movie) for movie in wiki_movies]

     # Read in the cleaned movies list from Step 4 as a DataFrame.
    cleaned_wiki_movies_df = pd.DataFrame(cleaned_wiki_movies)

    # Write a try-except block to catch errors while extracting the IMDb ID using a regular expression string and
    #  dropping any imdb_id duplicates. If there is an error, capture and print the exception.
    try:
        cleaned_wiki_movies_df["imdb_id"] = cleaned_wiki_movies_df['imdb_link'].str.extract(r"(tt\d{7})")
        cleaned_wiki_movies_df.drop_duplicates(subset="imdb_id", inplace=True)
    except Exception as e: print(e)

      #  Write a list comprehension to keep the columns that don't have null values from the wiki_movies_df DataFrame.
    non_null_columns = [column for column in cleaned_wiki_movies_df.columns \
                        if cleaned_wiki_movies_df[column].isnull().sum() < (0.9 * len(cleaned_wiki_movies_df))]
    wiki_movies_df = cleaned_wiki_movies_df[non_null_columns]
    
    # Create a variable that will hold the non-null values from the “Box office” column.
    box_office = wiki_movies_df["Box office"].dropna()
    
    # Convert the box office data created in Step 8 to string values using the lambda and join functions.
    box_office = box_office.apply(lambda x: ' '.join(x) if x == list else x)

    # Write a regular expression to match the six elements of "form_one" of the box office data.
    form_one = r"\$\s*\d+\.?\d*\s*[mb]illi?on"
    
    # Write a regular expression to match the three elements of "form_two" of the box office data.
    form_two = r"\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)"

    # Add the parse_dollars function.
    def parse_dollars(s):
        if type(s) != str:
            return np.nan
    
        # In the form $###.# million ?
        if re.match(r'\$\s*\d+\.?\d*\s*milli?on', s, flags=re.IGNORECASE):
            # remove dollar sign and "million"
            s = re.sub('\$|\s|[a-zA-Z]', '', s)
            value = float(s) * 10**6
            return value
    
        # In the the form $###.# billion ?
        elif re.match(r'\$\s*\d+\.?\d*\s*billi?on', s, flags=re.IGNORECASE):
            s = re.sub('\$|\s|[a-zA-Z]', '', s)
            value = float(s) * 10**9
            return value
    
        # In the form $###,###,### ?
        elif re.match(r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)', s, flags=re.IGNORECASE):    
            s = re.sub('\$|,', '', s)
            value = float(s)
            return value
    
        else:
            return np.nan
    
        
    # Clean the box office column in the wiki_movies_df DataFrame.
    wiki_movies_df['box_office'] = box_office.str.extract(f'({form_one}|{form_two})', \
                                                          flags=re.IGNORECASE)[0].apply(parse_dollars)
    wiki_movies_df.drop('Box office', axis=1, inplace=True)
    
    # Clean the budget column in the wiki_movies_df DataFrame.
    budget = wiki_movies_df['Budget'].dropna().apply(lambda x: ' '.join(x) if x == list else x)
    budget = budget.str.replace(r'\$.*[---–](?![a-z])', '$', regex=True)
    budget = budget.str.replace(r'\[\d+\]\s*', '')
    wiki_movies_df['budget'] = budget.str.extract(f'({form_one}|{form_two})', \
                                                  flags=re.IGNORECASE)[0].apply(parse_dollars)
    
    # Clean the release date column in the wiki_movies_df DataFrame.
    release_date = wiki_movies_df["Release date"].dropna().apply(lambda x: " ".join(x) if type(x) == list else x)
    date_form_one = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s[123]\d,\s\d{4}'
    date_form_two = r'\d{4}.[01]\d.[123]\d'
    date_form_three = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}'
    date_form_four = r'\d{4}'
    wiki_movies_df['release_date'] = pd.to_datetime(release_date.str.\
        extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})')[0], infer_datetime_format=True)
    
    # Clean the running time column in the wiki_movies_df DataFrame.
    running_time = wiki_movies_df['Running time'].dropna().apply(lambda x: " ".join(x) if type(x) == list else x)
    running_time_extract = running_time.str.extract(r'(\d+)\s*ho?u?r?s?\s*(\d*)|(\d+)\s*m')
    running_time_extract = running_time_extract.apply(lambda col: pd.to_numeric(col, errors='coerce')).fillna(0)
    wiki_movies_df['running_time'] = running_time_extract.apply(lambda row: row[0]*60 + row[1] if row[2] == 0 else row[2], axis=1)
    wiki_movies_df.drop('Running time', axis=1, inplace=True)
    
     
    # 2. Clean the Kaggle metadata.
    kaggle_metadata = kaggle_metadata[kaggle_metadata['adult'] == 'False'].drop('adult', axis=1)
    kaggle_metadata['video'] = kaggle_metadata['video'] == 'True'
    kaggle_metadata['budget'] = kaggle_metadata['budget'].astype(int)
    kaggle_metadata['id'] = pd.to_numeric(kaggle_metadata['id'], errors='raise')
    kaggle_metadata['popularity'] = pd.to_numeric(kaggle_metadata['popularity'], errors='raise')
    kaggle_metadata['release_date'] = pd.to_datetime(kaggle_metadata['release_date'])

    # 3. Merged the two DataFrames into the movies DataFrame.
    movies_df = pd.merge(wiki_movies_df, kaggle_metadata, on='imdb_id', suffixes=['_wiki','_kaggle'])

    # 4. Drop unnecessary columns from the merged DataFrame.
    movies_df.drop(columns=['title_wiki','release_date_wiki', 'Language', 'Production company(s)'], inplace=True)

    # 5. Add in the function to fill in the missing Kaggle data.
    def fill_missing_kaggle_data(df, kaggle_column, wiki_column):
        df[kaggle_column] = df.apply(lambda row: row[wiki_column] if row[kaggle_column] == 0 else row[kaggle_column], axis=1)
        df.drop(columns=wiki_column, inplace=True)

    # 6. Call the function in Step 5 with the DataFrame and columns as the arguments.
    fill_missing_kaggle_data(movies_df, 'runtime', 'running_time')
    fill_missing_kaggle_data(movies_df, 'budget_kaggle', 'budget_wiki')
    fill_missing_kaggle_data(movies_df, 'revenue', 'box_office')

    # 7. Filter the movies DataFrame for specific columns.
    movies_df.drop('video', axis=1, inplace=True)

    # 8. Rename the columns in the movies DataFrame.
    movies_df = movies_df.loc[:, ['imdb_id','id','title_kaggle','original_title','tagline','belongs_to_collection','url','imdb_link',
                       'runtime','budget_kaggle','revenue','release_date_kaggle','popularity','vote_average','vote_count',
                       'genres','original_language','overview','spoken_languages','Country',
                       'production_companies','production_countries','Distributor',
                       'Producer(s)','Director','Starring','Cinematography','Editor(s)','Writer(s)','Composer(s)','Based on']]

    movies_df.rename({'id':'kaggle_id',
                  'title_kaggle':'title',
                  'url':'wikipedia_url',
                  'budget_kaggle':'budget',
                  'release_date_kaggle':'release_date',
                  'Country':'country',
                  'Distributor':'distributor',
                  'Producer(s)':'producers',
                  'Director':'director',
                  'Starring':'starring',
                  'Cinematography':'cinematography',
                  'Editor(s)':'editors',
                  'Writer(s)':'writers',
                  'Composer(s)':'composers',
                  'Based on':'based_on'
                 }, axis='columns', inplace=True)

    # 9. Transform and merge the ratings DataFrame.
    ratings['timestamp'] = pd.to_datetime(ratings['timestamp'], unit='s')
    rating_counts = ratings.groupby(['movieId','rating'], as_index=False).count() \
                .rename({'userId':'count'}, axis=1) \
                .pivot(index='movieId',columns='rating', values='count')
    rating_counts.columns = ['rating_' + str(col) for col in rating_counts.columns]
    movies_with_ratings_df = pd.merge(movies_df, rating_counts, how='left', left_on='kaggle_id', right_index=True)
    movies_with_ratings_df[rating_counts.columns] = movies_with_ratings_df[rating_counts.columns].fillna(0)
    
    # Database engine connection
    # engine = create_engine(dialect+driver://username:password@host:port/database_name)
    db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Movies"
    # Create the database engine
    engine = create_engine(db_string)
    # Save movie_df to SQL table
    # Use 'replace' for the if_exists parameter so that the movies_df DataFrame data won't be added to the table again.
    movies_df.to_sql(name='movies', con=engine, if_exists='replace')
    
    connection = engine.raw_connection()
    cursor = connection.cursor()
    cursor.execute("DROP TABLE IF EXISTS ratings")  # Drop table if it already exists
    connection.commit()
    connection.close()   # Close the connection
    
    # Directory path to the 3 files
    file_dir = 'D:/Data_Visualization_and_Analytics_Boot_Camp/8_Challenge/Resources'
    
    # Start counting the imported rows
    rows_imported = 0

    start_time = time.time()   # Time how long the import takes.
    for data in pd.read_csv(f'{file_dir}/ratings.csv', chunksize=50000):
    
        print(f'Writing to DB Rows {rows_imported} to {rows_imported + len(data)}...', end='')

        data.to_sql(name='ratings', con=engine, if_exists='append')
    
        rows_imported += len(data)
    
        # Elapsed time
        print(f'Done. {time.time() - start_time} total seconds elapsed')
        
        # movies_df.head(10)
        # movies_df.tail(10)
        # movies_df.columns.to_list()

# %%
extract_transform_load()
# Out:
# D:\ProgramData\Anaconda3\envs\MachineLearningEnvironment\lib\site-packages\ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\ProgramData\Anaconda3\envs\MachineLearningEnvironment\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# D:\ProgramData\Anaconda3\envs\MachineLearningEnvironment\lib\site-packages\pandas\core\strings\object_array.py:156: FutureWarning: Possible set difference at position 6
#   pat = re.compile(pat, flags=flags)
# D:\ProgramData\Anaconda3\envs\MachineLearningEnvironment\lib\site-packages\ipykernel_launcher.py:84: FutureWarning: The default value of regex will change from True to False in a future version.
# D:\ProgramData\Anaconda3\envs\MachineLearningEnvironment\lib\site-packages\ipykernel_launcher.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\ProgramData\Anaconda3\envs\MachineLearningEnvironment\lib\site-packages\ipykernel_launcher.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\ProgramData\Anaconda3\envs\MachineLearningEnvironment\lib\site-packages\ipykernel_launcher.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Writing to DB Rows 0 to 50000...Done. 1.5261240005493164 total seconds elapsed
# Writing to DB Rows 50000 to 100000...Done. 2.9832868576049805 total seconds elapsed
# Writing to DB Rows 100000 to 150000...Done. 4.372488975524902 total seconds elapsed
# Writing to DB Rows 150000 to 200000...Done. 5.798465967178345 total seconds elapsed
# Writing to DB Rows 200000 to 250000...Done. 7.2234742641448975 total seconds elapsed
# Writing to DB Rows 250000 to 300000...Done. 8.552831649780273 total seconds elapsed
# Writing to DB Rows 300000 to 350000...Done. 9.801791667938232 total seconds elapsed
# Writing to DB Rows 350000 to 400000...Done. 11.101083755493164 total seconds elapsed
# Writing to DB Rows 400000 to 450000...Done. 12.331305742263794 total seconds elapsed
# Writing to DB Rows 450000 to 500000...Done. 13.678041934967041 total seconds elapsed
# Writing to DB Rows 500000 to 550000...Done. 14.94233226776123 total seconds elapsed
# Writing to DB Rows 550000 to 600000...Done. 16.1684467792511 total seconds elapsed
# Writing to DB Rows 600000 to 650000...Done. 17.476782083511353 total seconds elapsed
# Writing to DB Rows 650000 to 700000...Done. 18.71723246574402 total seconds elapsed
# Writing to DB Rows 700000 to 750000...Done. 20.028204441070557 total seconds elapsed
# Writing to DB Rows 750000 to 800000...Done. 21.269456386566162 total seconds elapsed
# Writing to DB Rows 800000 to 850000...Done. 22.74414038658142 total seconds elapsed
# Writing to DB Rows 850000 to 900000...Done. 24.007988452911377 total seconds elapsed
# Writing to DB Rows 900000 to 950000...Done. 25.31873917579651 total seconds elapsed
# Writing to DB Rows 950000 to 1000000...Done. 26.530960083007812 total seconds elapsed
# Writing to DB Rows 1000000 to 1050000...Done. 27.837328910827637 total seconds elapsed
# Writing to DB Rows 1050000 to 1100000...Done. 29.084904193878174 total seconds elapsed
# Writing to DB Rows 1100000 to 1150000...Done. 30.377530336380005 total seconds elapsed
# Writing to DB Rows 1150000 to 1200000...Done. 31.721251726150513 total seconds elapsed
# Writing to DB Rows 1200000 to 1250000...Done. 32.96917748451233 total seconds elapsed
# Writing to DB Rows 1250000 to 1300000...Done. 34.27257704734802 total seconds elapsed
# Writing to DB Rows 1300000 to 1350000...Done. 35.568740129470825 total seconds elapsed
# Writing to DB Rows 1350000 to 1400000...Done. 37.05146861076355 total seconds elapsed
# Writing to DB Rows 1400000 to 1450000...Done. 38.35063076019287 total seconds elapsed
# Writing to DB Rows 1450000 to 1500000...Done. 39.68141508102417 total seconds elapsed
# Writing to DB Rows 1500000 to 1550000...Done. 40.92378044128418 total seconds elapsed
# Writing to DB Rows 1550000 to 1600000...Done. 42.2403244972229 total seconds elapsed
# Writing to DB Rows 1600000 to 1650000...Done. 43.48751163482666 total seconds elapsed
# Writing to DB Rows 1650000 to 1700000...Done. 44.78791856765747 total seconds elapsed
# Writing to DB Rows 1700000 to 1750000...Done. 46.023279905319214 total seconds elapsed
# Writing to DB Rows 1750000 to 1800000...Done. 47.33006811141968 total seconds elapsed
# Writing to DB Rows 1800000 to 1850000...Done. 48.58135485649109 total seconds elapsed
# Writing to DB Rows 1850000 to 1900000...Done. 49.87564539909363 total seconds elapsed
# Writing to DB Rows 1900000 to 1950000...Done. 51.20286822319031 total seconds elapsed
# Writing to DB Rows 1950000 to 2000000...Done. 52.57536220550537 total seconds elapsed
# Writing to DB Rows 2000000 to 2050000...Done. 53.91817617416382 total seconds elapsed
# Writing to DB Rows 2050000 to 2100000...Done. 55.42024326324463 total seconds elapsed
# Writing to DB Rows 2100000 to 2150000...Done. 56.82783269882202 total seconds elapsed
# Writing to DB Rows 2150000 to 2200000...Done. 58.04117465019226 total seconds elapsed
# Writing to DB Rows 2200000 to 2250000...Done. 59.360753297805786 total seconds elapsed
# Writing to DB Rows 2250000 to 2300000...Done. 60.6180305480957 total seconds elapsed
# Writing to DB Rows 2300000 to 2350000...Done. 61.93050193786621 total seconds elapsed
# Writing to DB Rows 2350000 to 2400000...Done. 63.248448610305786 total seconds elapsed
# Writing to DB Rows 2400000 to 2450000...Done. 64.5647554397583 total seconds elapsed
# Writing to DB Rows 2450000 to 2500000...Done. 65.86133623123169 total seconds elapsed
# Writing to DB Rows 2500000 to 2550000...Done. 67.19641041755676 total seconds elapsed
# Writing to DB Rows 2550000 to 2600000...Done. 68.4484441280365 total seconds elapsed
# Writing to DB Rows 2600000 to 2650000...Done. 69.78619933128357 total seconds elapsed
# Writing to DB Rows 2650000 to 2700000...Done. 71.12894487380981 total seconds elapsed
# Writing to DB Rows 2700000 to 2750000...Done. 72.38904356956482 total seconds elapsed
# Writing to DB Rows 2750000 to 2800000...Done. 73.68786716461182 total seconds elapsed
# Writing to DB Rows 2800000 to 2850000...Done. 74.92595672607422 total seconds elapsed
# Writing to DB Rows 2850000 to 2900000...Done. 76.25817537307739 total seconds elapsed
# Writing to DB Rows 2900000 to 2950000...Done. 77.50380778312683 total seconds elapsed
# Writing to DB Rows 2950000 to 3000000...Done. 78.83296394348145 total seconds elapsed
# Writing to DB Rows 3000000 to 3050000...Done. 80.06144571304321 total seconds elapsed
# Writing to DB Rows 3050000 to 3100000...Done. 81.80886673927307 total seconds elapsed
# Writing to DB Rows 3100000 to 3150000...Done. 83.40599226951599 total seconds elapsed
# Writing to DB Rows 3150000 to 3200000...Done. 84.73813939094543 total seconds elapsed
# Writing to DB Rows 3200000 to 3250000...Done. 86.02136087417603 total seconds elapsed
# Writing to DB Rows 3250000 to 3300000...Done. 87.44515800476074 total seconds elapsed
# Writing to DB Rows 3300000 to 3350000...Done. 88.85902190208435 total seconds elapsed
# Writing to DB Rows 3350000 to 3400000...Done. 90.12546420097351 total seconds elapsed
# Writing to DB Rows 3400000 to 3450000...Done. 91.60429358482361 total seconds elapsed
# Writing to DB Rows 3450000 to 3500000...Done. 92.92091059684753 total seconds elapsed
# Writing to DB Rows 3500000 to 3550000...Done. 94.23150563240051 total seconds elapsed
# Writing to DB Rows 3550000 to 3600000...Done. 95.48237347602844 total seconds elapsed
# Writing to DB Rows 3600000 to 3650000...Done. 96.86758160591125 total seconds elapsed
# Writing to DB Rows 3650000 to 3700000...Done. 98.19391918182373 total seconds elapsed
# Writing to DB Rows 3700000 to 3750000...Done. 99.51478433609009 total seconds elapsed
# Writing to DB Rows 3750000 to 3800000...Done. 100.84326601028442 total seconds elapsed
# Writing to DB Rows 3800000 to 3850000...Done. 102.12012577056885 total seconds elapsed
# Writing to DB Rows 3850000 to 3900000...Done. 103.51661515235901 total seconds elapsed
# Writing to DB Rows 3900000 to 3950000...Done. 104.72558426856995 total seconds elapsed
# Writing to DB Rows 3950000 to 4000000...Done. 106.01484060287476 total seconds elapsed
# Writing to DB Rows 4000000 to 4050000...Done. 107.379812002182 total seconds elapsed
# Writing to DB Rows 4050000 to 4100000...Done. 108.69857501983643 total seconds elapsed
# Writing to DB Rows 4100000 to 4150000...Done. 109.95734739303589 total seconds elapsed
# Writing to DB Rows 4150000 to 4200000...Done. 111.22523880004883 total seconds elapsed
# Writing to DB Rows 4200000 to 4250000...Done. 112.5130033493042 total seconds elapsed
# Writing to DB Rows 4250000 to 4300000...Done. 113.76052665710449 total seconds elapsed
# Writing to DB Rows 4300000 to 4350000...Done. 115.14867925643921 total seconds elapsed
# Writing to DB Rows 4350000 to 4400000...Done. 116.39523506164551 total seconds elapsed
# Writing to DB Rows 4400000 to 4450000...Done. 117.73529958724976 total seconds elapsed
# Writing to DB Rows 4450000 to 4500000...Done. 119.08636021614075 total seconds elapsed
# Writing to DB Rows 4500000 to 4550000...Done. 120.42494583129883 total seconds elapsed
# Writing to DB Rows 4550000 to 4600000...Done. 121.66984629631042 total seconds elapsed
# Writing to DB Rows 4600000 to 4650000...Done. 123.02022671699524 total seconds elapsed
# Writing to DB Rows 4650000 to 4700000...Done. 124.39499187469482 total seconds elapsed
# Writing to DB Rows 4700000 to 4750000...Done. 125.63874101638794 total seconds elapsed
# Writing to DB Rows 4750000 to 4800000...Done. 126.9251058101654 total seconds elapsed
# Writing to DB Rows 4800000 to 4850000...Done. 128.19611167907715 total seconds elapsed
# Writing to DB Rows 4850000 to 4900000...Done. 129.50244760513306 total seconds elapsed
# Writing to DB Rows 4900000 to 4950000...Done. 130.77594995498657 total seconds elapsed
# Writing to DB Rows 4950000 to 5000000...Done. 132.11774682998657 total seconds elapsed
# Writing to DB Rows 5000000 to 5050000...Done. 133.371928691864 total seconds elapsed
# Writing to DB Rows 5050000 to 5100000...Done. 134.78556108474731 total seconds elapsed
# Writing to DB Rows 5100000 to 5150000...Done. 136.04506707191467 total seconds elapsed
# Writing to DB Rows 5150000 to 5200000...Done. 137.38325428962708 total seconds elapsed
# Writing to DB Rows 5200000 to 5250000...Done. 138.6479935646057 total seconds elapsed
# Writing to DB Rows 5250000 to 5300000...Done. 139.91251158714294 total seconds elapsed
# Writing to DB Rows 5300000 to 5350000...Done. 141.27714371681213 total seconds elapsed
# Writing to DB Rows 5350000 to 5400000...Done. 142.49344205856323 total seconds elapsed
# Writing to DB Rows 5400000 to 5450000...Done. 143.8329918384552 total seconds elapsed
# Writing to DB Rows 5450000 to 5500000...Done. 145.08558320999146 total seconds elapsed
# Writing to DB Rows 5500000 to 5550000...Done. 146.41015529632568 total seconds elapsed
# Writing to DB Rows 5550000 to 5600000...Done. 147.7414653301239 total seconds elapsed
# Writing to DB Rows 5600000 to 5650000...Done. 149.0299949645996 total seconds elapsed
# Writing to DB Rows 5650000 to 5700000...Done. 150.4430902004242 total seconds elapsed
# Writing to DB Rows 5700000 to 5750000...Done. 151.83846735954285 total seconds elapsed
# Writing to DB Rows 5750000 to 5800000...Done. 153.18098974227905 total seconds elapsed
# Writing to DB Rows 5800000 to 5850000...Done. 154.45177483558655 total seconds elapsed
# Writing to DB Rows 5850000 to 5900000...Done. 155.79995322227478 total seconds elapsed
# Writing to DB Rows 5900000 to 5950000...Done. 157.0302450656891 total seconds elapsed
# Writing to DB Rows 5950000 to 6000000...Done. 158.25266766548157 total seconds elapsed
# Writing to DB Rows 6000000 to 6050000...Done. 159.563170671463 total seconds elapsed
# Writing to DB Rows 6050000 to 6100000...Done. 160.84995484352112 total seconds elapsed
# Writing to DB Rows 6100000 to 6150000...Done. 162.2051296234131 total seconds elapsed
# Writing to DB Rows 6150000 to 6200000...Done. 163.50900793075562 total seconds elapsed
# Writing to DB Rows 6200000 to 6250000...Done. 164.8325548171997 total seconds elapsed
# Writing to DB Rows 6250000 to 6300000...Done. 166.11281991004944 total seconds elapsed
# Writing to DB Rows 6300000 to 6350000...Done. 167.43284225463867 total seconds elapsed
# Writing to DB Rows 6350000 to 6400000...Done. 168.77896547317505 total seconds elapsed
# Writing to DB Rows 6400000 to 6450000...Done. 170.04346656799316 total seconds elapsed
# Writing to DB Rows 6450000 to 6500000...Done. 171.37003207206726 total seconds elapsed
# Writing to DB Rows 6500000 to 6550000...Done. 172.6991834640503 total seconds elapsed
# Writing to DB Rows 6550000 to 6600000...Done. 174.0056390762329 total seconds elapsed
# Writing to DB Rows 6600000 to 6650000...Done. 175.3391501903534 total seconds elapsed
# Writing to DB Rows 6650000 to 6700000...Done. 176.68786358833313 total seconds elapsed
# Writing to DB Rows 6700000 to 6750000...Done. 177.93744373321533 total seconds elapsed
# Writing to DB Rows 6750000 to 6800000...Done. 179.24868202209473 total seconds elapsed
# Writing to DB Rows 6800000 to 6850000...Done. 180.576664686203 total seconds elapsed
# Writing to DB Rows 6850000 to 6900000...Done. 181.83839654922485 total seconds elapsed
# Writing to DB Rows 6900000 to 6950000...Done. 183.26415038108826 total seconds elapsed
# Writing to DB Rows 6950000 to 7000000...Done. 184.5471260547638 total seconds elapsed
# Writing to DB Rows 7000000 to 7050000...Done. 185.8273904323578 total seconds elapsed
# Writing to DB Rows 7050000 to 7100000...Done. 187.17641425132751 total seconds elapsed
# Writing to DB Rows 7100000 to 7150000...Done. 188.4632818698883 total seconds elapsed
# Writing to DB Rows 7150000 to 7200000...Done. 189.99577140808105 total seconds elapsed
# Writing to DB Rows 7200000 to 7250000...Done. 191.30037355422974 total seconds elapsed
# Writing to DB Rows 7250000 to 7300000...Done. 192.57084393501282 total seconds elapsed
# Writing to DB Rows 7300000 to 7350000...Done. 193.94289302825928 total seconds elapsed
# Writing to DB Rows 7350000 to 7400000...Done. 195.1749529838562 total seconds elapsed
# Writing to DB Rows 7400000 to 7450000...Done. 196.4808166027069 total seconds elapsed
# Writing to DB Rows 7450000 to 7500000...Done. 197.71599411964417 total seconds elapsed
# Writing to DB Rows 7500000 to 7550000...Done. 199.02937626838684 total seconds elapsed
# Writing to DB Rows 7550000 to 7600000...Done. 200.33803534507751 total seconds elapsed
# Writing to DB Rows 7600000 to 7650000...Done. 201.6278018951416 total seconds elapsed
# Writing to DB Rows 7650000 to 7700000...Done. 203.01705026626587 total seconds elapsed
# Writing to DB Rows 7700000 to 7750000...Done. 204.31709694862366 total seconds elapsed
# Writing to DB Rows 7750000 to 7800000...Done. 205.5951681137085 total seconds elapsed
# Writing to DB Rows 7800000 to 7850000...Done. 206.9438443183899 total seconds elapsed
# Writing to DB Rows 7850000 to 7900000...Done. 208.25252389907837 total seconds elapsed
# Writing to DB Rows 7900000 to 7950000...Done. 209.57406735420227 total seconds elapsed
# Writing to DB Rows 7950000 to 8000000...Done. 210.8059847354889 total seconds elapsed
# Writing to DB Rows 8000000 to 8050000...Done. 212.13014936447144 total seconds elapsed
# Writing to DB Rows 8050000 to 8100000...Done. 213.47837281227112 total seconds elapsed
# Writing to DB Rows 8100000 to 8150000...Done. 214.81910681724548 total seconds elapsed
# Writing to DB Rows 8150000 to 8200000...Done. 216.18737721443176 total seconds elapsed
# Writing to DB Rows 8200000 to 8250000...Done. 217.45286297798157 total seconds elapsed
# Writing to DB Rows 8250000 to 8300000...Done. 218.7190146446228 total seconds elapsed
# Writing to DB Rows 8300000 to 8350000...Done. 220.08422565460205 total seconds elapsed
# Writing to DB Rows 8350000 to 8400000...Done. 221.3889136314392 total seconds elapsed
# Writing to DB Rows 8400000 to 8450000...Done. 222.72448873519897 total seconds elapsed
# Writing to DB Rows 8450000 to 8500000...Done. 224.01378631591797 total seconds elapsed
# Writing to DB Rows 8500000 to 8550000...Done. 225.25426244735718 total seconds elapsed
# Writing to DB Rows 8550000 to 8600000...Done. 226.57878041267395 total seconds elapsed
# Writing to DB Rows 8600000 to 8650000...Done. 227.82728505134583 total seconds elapsed
# Writing to DB Rows 8650000 to 8700000...Done. 229.13453841209412 total seconds elapsed
# Writing to DB Rows 8700000 to 8750000...Done. 230.51176404953003 total seconds elapsed
# Writing to DB Rows 8750000 to 8800000...Done. 231.8749623298645 total seconds elapsed
# Writing to DB Rows 8800000 to 8850000...Done. 233.30906510353088 total seconds elapsed
# Writing to DB Rows 8850000 to 8900000...Done. 234.5603346824646 total seconds elapsed
# Writing to DB Rows 8900000 to 8950000...Done. 235.8871726989746 total seconds elapsed
# Writing to DB Rows 8950000 to 9000000...Done. 237.32692337036133 total seconds elapsed
# Writing to DB Rows 9000000 to 9050000...Done. 238.8360571861267 total seconds elapsed
# Writing to DB Rows 9050000 to 9100000...Done. 240.30722570419312 total seconds elapsed
# Writing to DB Rows 9100000 to 9150000...Done. 241.73739004135132 total seconds elapsed
# Writing to DB Rows 9150000 to 9200000...Done. 243.21054220199585 total seconds elapsed
# Writing to DB Rows 9200000 to 9250000...Done. 244.66172671318054 total seconds elapsed
# Writing to DB Rows 9250000 to 9300000...Done. 246.14485883712769 total seconds elapsed
# Writing to DB Rows 9300000 to 9350000...Done. 247.542053937912 total seconds elapsed
# Writing to DB Rows 9350000 to 9400000...Done. 248.83659648895264 total seconds elapsed
# Writing to DB Rows 9400000 to 9450000...Done. 250.15584111213684 total seconds elapsed
# Writing to DB Rows 9450000 to 9500000...Done. 251.40838813781738 total seconds elapsed
# Writing to DB Rows 9500000 to 9550000...Done. 252.65051531791687 total seconds elapsed
# Writing to DB Rows 9550000 to 9600000...Done. 253.95015859603882 total seconds elapsed
# Writing to DB Rows 9600000 to 9650000...Done. 255.27825260162354 total seconds elapsed
# Writing to DB Rows 9650000 to 9700000...Done. 256.53146982192993 total seconds elapsed
# Writing to DB Rows 9700000 to 9750000...Done. 257.8660674095154 total seconds elapsed
# Writing to DB Rows 9750000 to 9800000...Done. 259.2318856716156 total seconds elapsed
# Writing to DB Rows 9800000 to 9850000...Done. 260.5209045410156 total seconds elapsed
# Writing to DB Rows 9850000 to 9900000...Done. 261.803382396698 total seconds elapsed
# Writing to DB Rows 9900000 to 9950000...Done. 263.23455691337585 total seconds elapsed
# Writing to DB Rows 9950000 to 10000000...Done. 264.5360641479492 total seconds elapsed
# Writing to DB Rows 10000000 to 10050000...Done. 265.7899205684662 total seconds elapsed
# Writing to DB Rows 10050000 to 10100000...Done. 267.08619713783264 total seconds elapsed
# Writing to DB Rows 10100000 to 10150000...Done. 268.41189885139465 total seconds elapsed
# Writing to DB Rows 10150000 to 10200000...Done. 269.68872570991516 total seconds elapsed
# Writing to DB Rows 10200000 to 10250000...Done. 271.0061786174774 total seconds elapsed
# Writing to DB Rows 10250000 to 10300000...Done. 272.4202744960785 total seconds elapsed
# Writing to DB Rows 10300000 to 10350000...Done. 273.69120740890503 total seconds elapsed
# Writing to DB Rows 10350000 to 10400000...Done. 275.22260427474976 total seconds elapsed
# Writing to DB Rows 10400000 to 10450000...Done. 276.53058671951294 total seconds elapsed
# Writing to DB Rows 10450000 to 10500000...Done. 277.8195261955261 total seconds elapsed
# Writing to DB Rows 10500000 to 10550000...Done. 279.18075370788574 total seconds elapsed
# Writing to DB Rows 10550000 to 10600000...Done. 280.47498965263367 total seconds elapsed
# Writing to DB Rows 10600000 to 10650000...Done. 281.85143995285034 total seconds elapsed
# Writing to DB Rows 10650000 to 10700000...Done. 283.13301634788513 total seconds elapsed
# Writing to DB Rows 10700000 to 10750000...Done. 284.41055727005005 total seconds elapsed
# Writing to DB Rows 10750000 to 10800000...Done. 285.77958822250366 total seconds elapsed
# Writing to DB Rows 10800000 to 10850000...Done. 287.0661189556122 total seconds elapsed
# Writing to DB Rows 10850000 to 10900000...Done. 288.4197449684143 total seconds elapsed
# Writing to DB Rows 10900000 to 10950000...Done. 289.6750018596649 total seconds elapsed
# Writing to DB Rows 10950000 to 11000000...Done. 290.9292776584625 total seconds elapsed
# Writing to DB Rows 11000000 to 11050000...Done. 292.23590087890625 total seconds elapsed
# Writing to DB Rows 11050000 to 11100000...Done. 293.51092863082886 total seconds elapsed
# Writing to DB Rows 11100000 to 11150000...Done. 294.93195366859436 total seconds elapsed
# Writing to DB Rows 11150000 to 11200000...Done. 296.26434540748596 total seconds elapsed
# Writing to DB Rows 11200000 to 11250000...Done. 297.52156686782837 total seconds elapsed
# Writing to DB Rows 11250000 to 11300000...Done. 298.8311755657196 total seconds elapsed
# Writing to DB Rows 11300000 to 11350000...Done. 300.11407256126404 total seconds elapsed
# Writing to DB Rows 11350000 to 11400000...Done. 301.3800251483917 total seconds elapsed
# Writing to DB Rows 11400000 to 11450000...Done. 302.6996097564697 total seconds elapsed
# Writing to DB Rows 11450000 to 11500000...Done. 305.28657722473145 total seconds elapsed
# Writing to DB Rows 11500000 to 11550000...Done. 307.61493158340454 total seconds elapsed
# Writing to DB Rows 11550000 to 11600000...Done. 308.9706470966339 total seconds elapsed
# Writing to DB Rows 11600000 to 11650000...Done. 310.45181703567505 total seconds elapsed
# Writing to DB Rows 11650000 to 11700000...Done. 311.73408246040344 total seconds elapsed
# Writing to DB Rows 11700000 to 11750000...Done. 313.03548860549927 total seconds elapsed
# Writing to DB Rows 11750000 to 11800000...Done. 314.5376241207123 total seconds elapsed
# Writing to DB Rows 11800000 to 11850000...Done. 315.8644280433655 total seconds elapsed
# Writing to DB Rows 11850000 to 11900000...Done. 317.1490557193756 total seconds elapsed
# Writing to DB Rows 11900000 to 11950000...Done. 318.51729249954224 total seconds elapsed
# Writing to DB Rows 11950000 to 12000000...Done. 319.83852672576904 total seconds elapsed
# Writing to DB Rows 12000000 to 12050000...Done. 321.21750354766846 total seconds elapsed
# Writing to DB Rows 12050000 to 12100000...Done. 322.5275413990021 total seconds elapsed
# Writing to DB Rows 12100000 to 12150000...Done. 323.83379101753235 total seconds elapsed
# Writing to DB Rows 12150000 to 12200000...Done. 325.27696228027344 total seconds elapsed
# Writing to DB Rows 12200000 to 12250000...Done. 326.8320662975311 total seconds elapsed
# Writing to DB Rows 12250000 to 12300000...Done. 328.27532744407654 total seconds elapsed
# Writing to DB Rows 12300000 to 12350000...Done. 329.7344870567322 total seconds elapsed
# Writing to DB Rows 12350000 to 12400000...Done. 331.06769919395447 total seconds elapsed
# Writing to DB Rows 12400000 to 12450000...Done. 332.4380569458008 total seconds elapsed
# Writing to DB Rows 12450000 to 12500000...Done. 333.7505977153778 total seconds elapsed
# Writing to DB Rows 12500000 to 12550000...Done. 335.1079797744751 total seconds elapsed
# Writing to DB Rows 12550000 to 12600000...Done. 336.41221809387207 total seconds elapsed
# Writing to DB Rows 12600000 to 12650000...Done. 337.69846081733704 total seconds elapsed
# Writing to DB Rows 12650000 to 12700000...Done. 339.05927085876465 total seconds elapsed
# Writing to DB Rows 12700000 to 12750000...Done. 340.3365366458893 total seconds elapsed
# Writing to DB Rows 12750000 to 12800000...Done. 341.74072766304016 total seconds elapsed
# Writing to DB Rows 12800000 to 12850000...Done. 343.2978947162628 total seconds elapsed
# Writing to DB Rows 12850000 to 12900000...Done. 344.54911398887634 total seconds elapsed
# Writing to DB Rows 12900000 to 12950000...Done. 345.8668267726898 total seconds elapsed
# Writing to DB Rows 12950000 to 13000000...Done. 347.1191852092743 total seconds elapsed
# Writing to DB Rows 13000000 to 13050000...Done. 348.4399938583374 total seconds elapsed
# Writing to DB Rows 13050000 to 13100000...Done. 349.8075828552246 total seconds elapsed
# Writing to DB Rows 13100000 to 13150000...Done. 351.1333315372467 total seconds elapsed
# Writing to DB Rows 13150000 to 13200000...Done. 352.7144365310669 total seconds elapsed
# Writing to DB Rows 13200000 to 13250000...Done. 354.2825217247009 total seconds elapsed
# Writing to DB Rows 13250000 to 13300000...Done. 355.6947100162506 total seconds elapsed
# Writing to DB Rows 13300000 to 13350000...Done. 357.09892225265503 total seconds elapsed
# Writing to DB Rows 13350000 to 13400000...Done. 358.53707695007324 total seconds elapsed
# Writing to DB Rows 13400000 to 13450000...Done. 359.79365634918213 total seconds elapsed
# Writing to DB Rows 13450000 to 13500000...Done. 361.0967128276825 total seconds elapsed
# Writing to DB Rows 13500000 to 13550000...Done. 362.38473677635193 total seconds elapsed
# Writing to DB Rows 13550000 to 13600000...Done. 363.76230216026306 total seconds elapsed
# Writing to DB Rows 13600000 to 13650000...Done. 365.0700874328613 total seconds elapsed
# Writing to DB Rows 13650000 to 13700000...Done. 366.4257025718689 total seconds elapsed
# Writing to DB Rows 13700000 to 13750000...Done. 367.70960783958435 total seconds elapsed
# Writing to DB Rows 13750000 to 13800000...Done. 369.0374255180359 total seconds elapsed
# Writing to DB Rows 13800000 to 13850000...Done. 370.3826229572296 total seconds elapsed
# Writing to DB Rows 13850000 to 13900000...Done. 371.671101808548 total seconds elapsed
# Writing to DB Rows 13900000 to 13950000...Done. 372.9514248371124 total seconds elapsed
# Writing to DB Rows 13950000 to 14000000...Done. 374.4505937099457 total seconds elapsed
# Writing to DB Rows 14000000 to 14050000...Done. 375.7579548358917 total seconds elapsed
# Writing to DB Rows 14050000 to 14100000...Done. 377.0445704460144 total seconds elapsed
# Writing to DB Rows 14100000 to 14150000...Done. 378.3827564716339 total seconds elapsed
# Writing to DB Rows 14150000 to 14200000...Done. 379.67990899086 total seconds elapsed
# Writing to DB Rows 14200000 to 14250000...Done. 380.94168066978455 total seconds elapsed
# Writing to DB Rows 14250000 to 14300000...Done. 382.31234550476074 total seconds elapsed
# Writing to DB Rows 14300000 to 14350000...Done. 383.62247586250305 total seconds elapsed
# Writing to DB Rows 14350000 to 14400000...Done. 384.95127511024475 total seconds elapsed
# Writing to DB Rows 14400000 to 14450000...Done. 386.24733662605286 total seconds elapsed
# Writing to DB Rows 14450000 to 14500000...Done. 387.5262463092804 total seconds elapsed
# Writing to DB Rows 14500000 to 14550000...Done. 388.8088104724884 total seconds elapsed
# Writing to DB Rows 14550000 to 14600000...Done. 390.0900764465332 total seconds elapsed
# Writing to DB Rows 14600000 to 14650000...Done. 391.6152129173279 total seconds elapsed
# Writing to DB Rows 14650000 to 14700000...Done. 392.8874468803406 total seconds elapsed
# Writing to DB Rows 14700000 to 14750000...Done. 394.1470196247101 total seconds elapsed
# Writing to DB Rows 14750000 to 14800000...Done. 395.54853653907776 total seconds elapsed
# Writing to DB Rows 14800000 to 14850000...Done. 396.872275352478 total seconds elapsed
# Writing to DB Rows 14850000 to 14900000...Done. 398.140545129776 total seconds elapsed
# Writing to DB Rows 14900000 to 14950000...Done. 399.5252802371979 total seconds elapsed
# Writing to DB Rows 14950000 to 15000000...Done. 400.8532118797302 total seconds elapsed
# Writing to DB Rows 15000000 to 15050000...Done. 402.12437987327576 total seconds elapsed
# Writing to DB Rows 15050000 to 15100000...Done. 403.5061688423157 total seconds elapsed
# Writing to DB Rows 15100000 to 15150000...Done. 404.86569333076477 total seconds elapsed
# Writing to DB Rows 15150000 to 15200000...Done. 406.21691632270813 total seconds elapsed
# Writing to DB Rows 15200000 to 15250000...Done. 407.57714104652405 total seconds elapsed
# Writing to DB Rows 15250000 to 15300000...Done. 408.8726861476898 total seconds elapsed
# Writing to DB Rows 15300000 to 15350000...Done. 410.18551301956177 total seconds elapsed
# Writing to DB Rows 15350000 to 15400000...Done. 411.503160238266 total seconds elapsed
# Writing to DB Rows 15400000 to 15450000...Done. 412.8751263618469 total seconds elapsed
# Writing to DB Rows 15450000 to 15500000...Done. 414.1792562007904 total seconds elapsed
# Writing to DB Rows 15500000 to 15550000...Done. 415.4659764766693 total seconds elapsed
# Writing to DB Rows 15550000 to 15600000...Done. 416.8006796836853 total seconds elapsed
# Writing to DB Rows 15600000 to 15650000...Done. 418.0603482723236 total seconds elapsed
# Writing to DB Rows 15650000 to 15700000...Done. 419.36706614494324 total seconds elapsed
# Writing to DB Rows 15700000 to 15750000...Done. 420.7178452014923 total seconds elapsed
# Writing to DB Rows 15750000 to 15800000...Done. 422.060697555542 total seconds elapsed
# Writing to DB Rows 15800000 to 15850000...Done. 423.4382281303406 total seconds elapsed
# Writing to DB Rows 15850000 to 15900000...Done. 424.8896481990814 total seconds elapsed
# Writing to DB Rows 15900000 to 15950000...Done. 426.2070963382721 total seconds elapsed
# Writing to DB Rows 15950000 to 16000000...Done. 427.50251483917236 total seconds elapsed
# Writing to DB Rows 16000000 to 16050000...Done. 428.85343503952026 total seconds elapsed
# Writing to DB Rows 16050000 to 16100000...Done. 430.11625266075134 total seconds elapsed
# Writing to DB Rows 16100000 to 16150000...Done. 431.40066146850586 total seconds elapsed
# Writing to DB Rows 16150000 to 16200000...Done. 432.78133845329285 total seconds elapsed
# Writing to DB Rows 16200000 to 16250000...Done. 434.11000514030457 total seconds elapsed
# Writing to DB Rows 16250000 to 16300000...Done. 435.42982745170593 total seconds elapsed
# Writing to DB Rows 16300000 to 16350000...Done. 436.7892732620239 total seconds elapsed
# Writing to DB Rows 16350000 to 16400000...Done. 438.15254306793213 total seconds elapsed
# Writing to DB Rows 16400000 to 16450000...Done. 439.49662709236145 total seconds elapsed
# Writing to DB Rows 16450000 to 16500000...Done. 440.8622844219208 total seconds elapsed
# Writing to DB Rows 16500000 to 16550000...Done. 442.13168716430664 total seconds elapsed
# Writing to DB Rows 16550000 to 16600000...Done. 443.4221541881561 total seconds elapsed
# Writing to DB Rows 16600000 to 16650000...Done. 444.80293226242065 total seconds elapsed
# Writing to DB Rows 16650000 to 16700000...Done. 446.06481647491455 total seconds elapsed
# Writing to DB Rows 16700000 to 16750000...Done. 447.3385181427002 total seconds elapsed
# Writing to DB Rows 16750000 to 16800000...Done. 448.67112016677856 total seconds elapsed
# Writing to DB Rows 16800000 to 16850000...Done. 449.9110481739044 total seconds elapsed
# Writing to DB Rows 16850000 to 16900000...Done. 451.1706120967865 total seconds elapsed
# Writing to DB Rows 16900000 to 16950000...Done. 452.6081688404083 total seconds elapsed
# Writing to DB Rows 16950000 to 17000000...Done. 453.96333932876587 total seconds elapsed
# Writing to DB Rows 17000000 to 17050000...Done. 455.2645893096924 total seconds elapsed
# Writing to DB Rows 17050000 to 17100000...Done. 456.60822916030884 total seconds elapsed
# Writing to DB Rows 17100000 to 17150000...Done. 457.894816160202 total seconds elapsed
# Writing to DB Rows 17150000 to 17200000...Done. 459.1781554222107 total seconds elapsed
# Writing to DB Rows 17200000 to 17250000...Done. 460.5472972393036 total seconds elapsed
# Writing to DB Rows 17250000 to 17300000...Done. 461.79273104667664 total seconds elapsed
# Writing to DB Rows 17300000 to 17350000...Done. 463.06569051742554 total seconds elapsed
# Writing to DB Rows 17350000 to 17400000...Done. 464.43996143341064 total seconds elapsed
# Writing to DB Rows 17400000 to 17450000...Done. 465.7049024105072 total seconds elapsed
# Writing to DB Rows 17450000 to 17500000...Done. 467.0087218284607 total seconds elapsed
# Writing to DB Rows 17500000 to 17550000...Done. 468.38279390335083 total seconds elapsed
# Writing to DB Rows 17550000 to 17600000...Done. 469.6494460105896 total seconds elapsed
# Writing to DB Rows 17600000 to 17650000...Done. 471.02481722831726 total seconds elapsed
# Writing to DB Rows 17650000 to 17700000...Done. 472.3846204280853 total seconds elapsed
# Writing to DB Rows 17700000 to 17750000...Done. 473.7452359199524 total seconds elapsed
# Writing to DB Rows 17750000 to 17800000...Done. 475.0342707633972 total seconds elapsed
# Writing to DB Rows 17800000 to 17850000...Done. 476.41735553741455 total seconds elapsed
# Writing to DB Rows 17850000 to 17900000...Done. 477.712078332901 total seconds elapsed
# Writing to DB Rows 17900000 to 17950000...Done. 478.975056886673 total seconds elapsed
# Writing to DB Rows 17950000 to 18000000...Done. 480.4462113380432 total seconds elapsed
# Writing to DB Rows 18000000 to 18050000...Done. 481.73275542259216 total seconds elapsed
# Writing to DB Rows 18050000 to 18100000...Done. 483.03372597694397 total seconds elapsed
# Writing to DB Rows 18100000 to 18150000...Done. 484.37076926231384 total seconds elapsed
# Writing to DB Rows 18150000 to 18200000...Done. 485.6657757759094 total seconds elapsed
# Writing to DB Rows 18200000 to 18250000...Done. 487.0754499435425 total seconds elapsed
# Writing to DB Rows 18250000 to 18300000...Done. 488.42740654945374 total seconds elapsed
# Writing to DB Rows 18300000 to 18350000...Done. 489.72973895072937 total seconds elapsed
# Writing to DB Rows 18350000 to 18400000...Done. 491.0429892539978 total seconds elapsed
# Writing to DB Rows 18400000 to 18450000...Done. 492.4459035396576 total seconds elapsed
# Writing to DB Rows 18450000 to 18500000...Done. 493.67965030670166 total seconds elapsed
# Writing to DB Rows 18500000 to 18550000...Done. 495.0613889694214 total seconds elapsed
# Writing to DB Rows 18550000 to 18600000...Done. 496.48824977874756 total seconds elapsed
# Writing to DB Rows 18600000 to 18650000...Done. 497.8392655849457 total seconds elapsed
# Writing to DB Rows 18650000 to 18700000...Done. 499.11910581588745 total seconds elapsed
# Writing to DB Rows 18700000 to 18750000...Done. 500.53622174263 total seconds elapsed
# Writing to DB Rows 18750000 to 18800000...Done. 501.80844140052795 total seconds elapsed
# Writing to DB Rows 18800000 to 18850000...Done. 503.220636844635 total seconds elapsed
# Writing to DB Rows 18850000 to 18900000...Done. 504.5912194252014 total seconds elapsed
# Writing to DB Rows 18900000 to 18950000...Done. 505.86539912223816 total seconds elapsed
# Writing to DB Rows 18950000 to 19000000...Done. 507.13618564605713 total seconds elapsed
# Writing to DB Rows 19000000 to 19050000...Done. 508.528626203537 total seconds elapsed
# Writing to DB Rows 19050000 to 19100000...Done. 509.79212474823 total seconds elapsed
# Writing to DB Rows 19100000 to 19150000...Done. 511.06966972351074 total seconds elapsed
# Writing to DB Rows 19150000 to 19200000...Done. 512.5104789733887 total seconds elapsed
# Writing to DB Rows 19200000 to 19250000...Done. 513.8079662322998 total seconds elapsed
# Writing to DB Rows 19250000 to 19300000...Done. 515.0696215629578 total seconds elapsed
# Writing to DB Rows 19300000 to 19350000...Done. 516.4410729408264 total seconds elapsed
# Writing to DB Rows 19350000 to 19400000...Done. 517.7153120040894 total seconds elapsed
# Writing to DB Rows 19400000 to 19450000...Done. 519.1417925357819 total seconds elapsed
# Writing to DB Rows 19450000 to 19500000...Done. 520.4313933849335 total seconds elapsed
# Writing to DB Rows 19500000 to 19550000...Done. 521.8302807807922 total seconds elapsed
# Writing to DB Rows 19550000 to 19600000...Done. 523.1039729118347 total seconds elapsed
# Writing to DB Rows 19600000 to 19650000...Done. 524.4400284290314 total seconds elapsed
# Writing to DB Rows 19650000 to 19700000...Done. 525.8323006629944 total seconds elapsed
# Writing to DB Rows 19700000 to 19750000...Done. 527.1355459690094 total seconds elapsed
# Writing to DB Rows 19750000 to 19800000...Done. 528.6266956329346 total seconds elapsed
# Writing to DB Rows 19800000 to 19850000...Done. 530.0599462985992 total seconds elapsed
# Writing to DB Rows 19850000 to 19900000...Done. 531.496565580368 total seconds elapsed
# Writing to DB Rows 19900000 to 19950000...Done. 532.828262090683 total seconds elapsed
# Writing to DB Rows 19950000 to 20000000...Done. 534.202470779419 total seconds elapsed
# Writing to DB Rows 20000000 to 20050000...Done. 535.5047633647919 total seconds elapsed
# Writing to DB Rows 20050000 to 20100000...Done. 536.8038234710693 total seconds elapsed
# Writing to DB Rows 20100000 to 20150000...Done. 538.16601395607 total seconds elapsed
# Writing to DB Rows 20150000 to 20200000...Done. 539.4377262592316 total seconds elapsed
# Writing to DB Rows 20200000 to 20250000...Done. 540.7841804027557 total seconds elapsed
# Writing to DB Rows 20250000 to 20300000...Done. 542.1319360733032 total seconds elapsed
# Writing to DB Rows 20300000 to 20350000...Done. 543.4812133312225 total seconds elapsed
# Writing to DB Rows 20350000 to 20400000...Done. 544.865460395813 total seconds elapsed
# Writing to DB Rows 20400000 to 20450000...Done. 546.1768443584442 total seconds elapsed
# Writing to DB Rows 20450000 to 20500000...Done. 547.4141094684601 total seconds elapsed
# Writing to DB Rows 20500000 to 20550000...Done. 548.7849049568176 total seconds elapsed
# Writing to DB Rows 20550000 to 20600000...Done. 550.0941524505615 total seconds elapsed
# Writing to DB Rows 20600000 to 20650000...Done. 551.4454915523529 total seconds elapsed
# Writing to DB Rows 20650000 to 20700000...Done. 552.7758326530457 total seconds elapsed
# Writing to DB Rows 20700000 to 20750000...Done. 554.0393514633179 total seconds elapsed
# Writing to DB Rows 20750000 to 20800000...Done. 555.2724225521088 total seconds elapsed
# Writing to DB Rows 20800000 to 20850000...Done. 556.5287945270538 total seconds elapsed
# Writing to DB Rows 20850000 to 20900000...Done. 557.8843665122986 total seconds elapsed
# Writing to DB Rows 20900000 to 20950000...Done. 559.1743159294128 total seconds elapsed
# Writing to DB Rows 20950000 to 21000000...Done. 560.4944944381714 total seconds elapsed
# Writing to DB Rows 21000000 to 21050000...Done. 561.7959525585175 total seconds elapsed
# Writing to DB Rows 21050000 to 21100000...Done. 563.1386148929596 total seconds elapsed
# Writing to DB Rows 21100000 to 21150000...Done. 564.432564496994 total seconds elapsed
# Writing to DB Rows 21150000 to 21200000...Done. 565.695837020874 total seconds elapsed
# Writing to DB Rows 21200000 to 21250000...Done. 567.2560369968414 total seconds elapsed
# Writing to DB Rows 21250000 to 21300000...Done. 568.5194578170776 total seconds elapsed
# Writing to DB Rows 21300000 to 21350000...Done. 569.8529489040375 total seconds elapsed
# Writing to DB Rows 21350000 to 21400000...Done. 571.2012889385223 total seconds elapsed
# Writing to DB Rows 21400000 to 21450000...Done. 572.55370926857 total seconds elapsed
# Writing to DB Rows 21450000 to 21500000...Done. 573.8552603721619 total seconds elapsed
# Writing to DB Rows 21500000 to 21550000...Done. 575.1331789493561 total seconds elapsed
# Writing to DB Rows 21550000 to 21600000...Done. 576.4833850860596 total seconds elapsed
# Writing to DB Rows 21600000 to 21650000...Done. 577.7565822601318 total seconds elapsed
# Writing to DB Rows 21650000 to 21700000...Done. 579.0504138469696 total seconds elapsed
# Writing to DB Rows 21700000 to 21750000...Done. 580.4541664123535 total seconds elapsed
# Writing to DB Rows 21750000 to 21800000...Done. 581.735205411911 total seconds elapsed
# Writing to DB Rows 21800000 to 21850000...Done. 583.146963596344 total seconds elapsed
# Writing to DB Rows 21850000 to 21900000...Done. 584.4162640571594 total seconds elapsed
# Writing to DB Rows 21900000 to 21950000...Done. 585.7967894077301 total seconds elapsed
# Writing to DB Rows 21950000 to 22000000...Done. 587.0806879997253 total seconds elapsed
# Writing to DB Rows 22000000 to 22050000...Done. 588.3469033241272 total seconds elapsed
# Writing to DB Rows 22050000 to 22100000...Done. 589.6134297847748 total seconds elapsed
# Writing to DB Rows 22100000 to 22150000...Done. 590.971185207367 total seconds elapsed
# Writing to DB Rows 22150000 to 22200000...Done. 592.2723844051361 total seconds elapsed
# Writing to DB Rows 22200000 to 22250000...Done. 593.593649148941 total seconds elapsed
# Writing to DB Rows 22250000 to 22300000...Done. 594.9597718715668 total seconds elapsed
# Writing to DB Rows 22300000 to 22350000...Done. 596.2370343208313 total seconds elapsed
# Writing to DB Rows 22350000 to 22400000...Done. 597.6667723655701 total seconds elapsed
# Writing to DB Rows 22400000 to 22450000...Done. 599.0443584918976 total seconds elapsed
# Writing to DB Rows 22450000 to 22500000...Done. 600.5503597259521 total seconds elapsed
# Writing to DB Rows 22500000 to 22550000...Done. 602.4217224121094 total seconds elapsed
# Writing to DB Rows 22550000 to 22600000...Done. 603.7473130226135 total seconds elapsed
# Writing to DB Rows 22600000 to 22650000...Done. 605.0095891952515 total seconds elapsed
# Writing to DB Rows 22650000 to 22700000...Done. 606.3683199882507 total seconds elapsed
# Writing to DB Rows 22700000 to 22750000...Done. 607.6568851470947 total seconds elapsed
# Writing to DB Rows 22750000 to 22800000...Done. 608.9805274009705 total seconds elapsed
# Writing to DB Rows 22800000 to 22850000...Done. 610.2604942321777 total seconds elapsed
# Writing to DB Rows 22850000 to 22900000...Done. 611.5399060249329 total seconds elapsed
# Writing to DB Rows 22900000 to 22950000...Done. 612.8962745666504 total seconds elapsed
# Writing to DB Rows 22950000 to 23000000...Done. 614.2038140296936 total seconds elapsed
# Writing to DB Rows 23000000 to 23050000...Done. 615.644464969635 total seconds elapsed
# Writing to DB Rows 23050000 to 23100000...Done. 616.9794518947601 total seconds elapsed
# Writing to DB Rows 23100000 to 23150000...Done. 618.3499431610107 total seconds elapsed
# Writing to DB Rows 23150000 to 23200000...Done. 619.6341388225555 total seconds elapsed
# Writing to DB Rows 23200000 to 23250000...Done. 621.0622656345367 total seconds elapsed
# Writing to DB Rows 23250000 to 23300000...Done. 622.3622136116028 total seconds elapsed
# Writing to DB Rows 23300000 to 23350000...Done. 623.7125897407532 total seconds elapsed
# Writing to DB Rows 23350000 to 23400000...Done. 625.0461421012878 total seconds elapsed
# Writing to DB Rows 23400000 to 23450000...Done. 626.4301609992981 total seconds elapsed
# Writing to DB Rows 23450000 to 23500000...Done. 627.6978266239166 total seconds elapsed
# Writing to DB Rows 23500000 to 23550000...Done. 628.9881098270416 total seconds elapsed
# Writing to DB Rows 23550000 to 23600000...Done. 630.3483624458313 total seconds elapsed
# Writing to DB Rows 23600000 to 23650000...Done. 631.865513086319 total seconds elapsed
# Writing to DB Rows 23650000 to 23700000...Done. 633.1578476428986 total seconds elapsed
# Writing to DB Rows 23700000 to 23750000...Done. 634.5180103778839 total seconds elapsed
# Writing to DB Rows 23750000 to 23800000...Done. 635.8073151111603 total seconds elapsed
# Writing to DB Rows 23800000 to 23850000...Done. 637.1917238235474 total seconds elapsed
# Writing to DB Rows 23850000 to 23900000...Done. 638.4659628868103 total seconds elapsed
# Writing to DB Rows 23900000 to 23950000...Done. 639.7743616104126 total seconds elapsed
# Writing to DB Rows 23950000 to 24000000...Done. 641.3643636703491 total seconds elapsed
# Writing to DB Rows 24000000 to 24050000...Done. 642.6689562797546 total seconds elapsed
# Writing to DB Rows 24050000 to 24100000...Done. 643.981166601181 total seconds elapsed
# Writing to DB Rows 24100000 to 24150000...Done. 645.3072295188904 total seconds elapsed
# Writing to DB Rows 24150000 to 24200000...Done. 646.6696798801422 total seconds elapsed
# Writing to DB Rows 24200000 to 24250000...Done. 648.0238380432129 total seconds elapsed
# Writing to DB Rows 24250000 to 24300000...Done. 649.3358218669891 total seconds elapsed
# Writing to DB Rows 24300000 to 24350000...Done. 650.6296768188477 total seconds elapsed
# Writing to DB Rows 24350000 to 24400000...Done. 651.93900847435 total seconds elapsed
# Writing to DB Rows 24400000 to 24450000...Done. 653.3611235618591 total seconds elapsed
# Writing to DB Rows 24450000 to 24500000...Done. 654.8782594203949 total seconds elapsed
# Writing to DB Rows 24500000 to 24550000...Done. 656.1404991149902 total seconds elapsed
# Writing to DB Rows 24550000 to 24600000...Done. 657.3877787590027 total seconds elapsed
# Writing to DB Rows 24600000 to 24650000...Done. 658.6719160079956 total seconds elapsed
# Writing to DB Rows 24650000 to 24700000...Done. 659.981650352478 total seconds elapsed
# Writing to DB Rows 24700000 to 24750000...Done. 661.3331305980682 total seconds elapsed
# Writing to DB Rows 24750000 to 24800000...Done. 662.7545974254608 total seconds elapsed
# Writing to DB Rows 24800000 to 24850000...Done. 664.0184283256531 total seconds elapsed
# Writing to DB Rows 24850000 to 24900000...Done. 665.3503034114838 total seconds elapsed
# Writing to DB Rows 24900000 to 24950000...Done. 667.0073506832123 total seconds elapsed
# Writing to DB Rows 24950000 to 25000000...Done. 668.5064885616302 total seconds elapsed
# Writing to DB Rows 25000000 to 25050000...Done. 670.0755882263184 total seconds elapsed
# Writing to DB Rows 25050000 to 25100000...Done. 671.5067660808563 total seconds elapsed
# Writing to DB Rows 25100000 to 25150000...Done. 672.8221266269684 total seconds elapsed
# Writing to DB Rows 25150000 to 25200000...Done. 674.1054480075836 total seconds elapsed
# Writing to DB Rows 25200000 to 25250000...Done. 675.4006989002228 total seconds elapsed
# Writing to DB Rows 25250000 to 25300000...Done. 676.7051329612732 total seconds elapsed
# Writing to DB Rows 25300000 to 25350000...Done. 678.0746011734009 total seconds elapsed
# Writing to DB Rows 25350000 to 25400000...Done. 679.504768371582 total seconds elapsed
# Writing to DB Rows 25400000 to 25450000...Done. 680.7922441959381 total seconds elapsed
# Writing to DB Rows 25450000 to 25500000...Done. 682.06693816185 total seconds elapsed
# Writing to DB Rows 25500000 to 25550000...Done. 683.3544385433197 total seconds elapsed
# Writing to DB Rows 25550000 to 25600000...Done. 684.8435816764832 total seconds elapsed
# Writing to DB Rows 25600000 to 25650000...Done. 686.3926975727081 total seconds elapsed
# Writing to DB Rows 25650000 to 25700000...Done. 687.71484208107 total seconds elapsed
# Writing to DB Rows 25700000 to 25750000...Done. 688.9860301017761 total seconds elapsed
# Writing to DB Rows 25750000 to 25800000...Done. 690.3272337913513 total seconds elapsed
# Writing to DB Rows 25800000 to 25850000...Done. 691.6705622673035 total seconds elapsed
# Writing to DB Rows 25850000 to 25900000...Done. 692.9858877658844 total seconds elapsed
# Writing to DB Rows 25900000 to 25950000...Done. 694.3501751422882 total seconds elapsed
# Writing to DB Rows 25950000 to 26000000...Done. 695.7504658699036 total seconds elapsed
# Writing to DB Rows 26000000 to 26024289...Done. 696.3499789237976 total seconds elapsed
